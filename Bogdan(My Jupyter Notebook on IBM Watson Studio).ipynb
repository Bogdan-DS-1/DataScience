# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __BOGDAN
# Data Scientist in Healthcare__

# %% [markdown]
# _I am interested in data science becuase I am fascinated with the future. I love statistics and enjoy the idea of leveraging powerful computers to help solve real world problems_

# %% [markdown]
# ### The Code in the next well will do a simple addition problem:

# %%
x=3
print(x+2)
# Out:
# 5

# %% [markdown]
# - Bullet 1
# - Bullet 1
# - Bullet 3
# - Bullet 4
#
# This like below is the horiontal rule.
#
#  ---
